# %%
import pandas as pd
df = pd.read_csv("diabetes.csv")
df.columns = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
df.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
df.tail()
# Out:
#      pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 763        10      101  76    48      180  32.9     0.171   63      0
# 764         2      122  70    27        0  36.8     0.340   27      0
# 765         5      121  72    23      112  26.2     0.245   30      0
# 766         1      126  60     0        0  30.1     0.349   47      1
# 767         1       93  70    31        0  30.4     0.315   23      0

# %%
from pycaret.classification import *
exp1 = setup(df, target = 'label')
# Out:
# <style  type="text/css" >
# </style><table id="T_9fc03_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9fc03_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9fc03_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_9fc03_row0_col1" class="data row0 col1" >5794</td>
#             </tr>
#             <tr>
#                         <th id="T_9fc03_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9fc03_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_9fc03_row1_col1" class="data row1 col1" >label</td>
#             </tr>
#             <tr>
#                         <th id="T_9fc03_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_f960b_ th {
#           text-align: left;
# ...

# %%
logistic = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_3db1d_row10_col0,#T_3db1d_row10_col1,#T_3db1d_row10_col2,#T_3db1d_row10_col3,#T_3db1d_row10_col4,#T_3db1d_row10_col5,#T_3db1d_row10_col6{
#             background:  yellow;
#         }</style><table id="T_3db1d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3db1d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3db1d_row0_col0" class="data row0 col0" >0.6852</td>
# ...

# %%
lr = create_model('lr')
tuned_lr = tune_model(lr)
# Out:
# <style  type="text/css" >
# #T_76364_row10_col0,#T_76364_row10_col1,#T_76364_row10_col2,#T_76364_row10_col3,#T_76364_row10_col4,#T_76364_row10_col5,#T_76364_row10_col6{
#             background:  yellow;
#         }</style><table id="T_76364_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76364_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76364_row0_col0" class="data row0 col0" >0.6852</td>
# ...

# %%
tuned_lr = tune_model(lr, n_iter = 50)
tuned_lr = tune_model(lr, optimize = 'AUC') #default is 'Accuracy'
# Out:
# <style  type="text/css" >
# #T_bcf4d_row10_col0,#T_bcf4d_row10_col1,#T_bcf4d_row10_col2,#T_bcf4d_row10_col3,#T_bcf4d_row10_col4,#T_bcf4d_row10_col5,#T_bcf4d_row10_col6{
#             background:  yellow;
#         }</style><table id="T_bcf4d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcf4d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bcf4d_row0_col0" class="data row0 col0" >0.7407</td>
# ...

# %%
#ensembling-bagging
lr = create_model('lr')
lr_bagged = ensemble_model(lr)
# Out:
# <style  type="text/css" >
# #T_01eae_row10_col0,#T_01eae_row10_col1,#T_01eae_row10_col2,#T_01eae_row10_col3,#T_01eae_row10_col4,#T_01eae_row10_col5,#T_01eae_row10_col6{
#             background:  yellow;
#         }</style><table id="T_01eae_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_01eae_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_01eae_row0_col0" class="data row0 col0" >0.6852</td>
# ...

# %%
#ensembling-bagging
lr = create_model('lr')
lr_boosting = ensemble_model(lr, method='Boosting')
# Out:
# <style  type="text/css" >
# #T_eccb8_row10_col0,#T_eccb8_row10_col1,#T_eccb8_row10_col2,#T_eccb8_row10_col3,#T_eccb8_row10_col4,#T_eccb8_row10_col5,#T_eccb8_row10_col6{
#             background:  yellow;
#         }</style><table id="T_eccb8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eccb8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eccb8_row0_col0" class="data row0 col0" >0.7593</td>
# ...

# %%
evaluate_model(lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
